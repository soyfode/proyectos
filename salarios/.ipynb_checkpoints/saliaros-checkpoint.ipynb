# %% [markdown]
# # Diferencia de salarios entre hombres y mujeres

# %%
# librerias
import pandas as pd

# %%
data = pd.read_excel('salarios.xlsx',usecols="B:K",skiprows=3)
data.head()
# Out:
#     Apellido   Nombre  Edad    Género       Pais     Etnia Fecha_de_inicio  \
# 0     Martin   Sandra    30  Femenino     EE.UU.  Asiática      2013-11-11
# 1   Warfield    Sarah    39  Femenino     EE.UU.  Asiática      2015-03-30
# 2  Petrowsky   Thelma    33  Femenino     EE.UU.  Asiática      2014-11-10
# 3   Boutwell  Bonalyn    30  Femenino     EE.UU.  Asiática      2015-02-16
# 4  Petingill    Shana    38  Femenino  Australia  Asiática      2012-04-02
#
#                Departamento                         Posición   Salario
# 0    Ingeniería de Software              Ingeniero de ventas  115460.8
# 1                     TI/SI           Ingeniero de redes Sr.  114816.0
# 2                     TI/SI  Administrador de bases de datos   88920.0
# 3  Oficinas Administrativas                     Contador Sr.   72696.0
# 4                Producción         Técnico de producción II   54080.0

# %% [markdown]
# ## Test de Hipótesis

# %% [markdown]
# - El salario masculino promedio es igual al femenino promedio
# $$H_0: \mu_m - \mu_f = 0 $$
#
# - El salario masculino promedio difiere al femenino promedio
# $$H_1: \mu_m - \mu_f \neq 0$$

# %% [markdown]
# ### Cantidad de hombres y mujeres

# %%
data[data["Género"]=='Femenino']
# Out:
#          Apellido    Nombre  Edad    Género       Pais                  Etnia  \
# 0          Martin    Sandra    30  Femenino     EE.UU.               Asiática
# 1        Warfield     Sarah    39  Femenino     EE.UU.               Asiática
# 2       Petrowsky    Thelma    33  Femenino     EE.UU.               Asiática
# 3        Boutwell   Bonalyn    30  Femenino     EE.UU.               Asiática
# 4       Petingill     Shana    38  Femenino  Australia               Asiática
# ..            ...       ...   ...       ...        ...                    ...
# 93       Jeannite    Tayana    31  Femenino     EE.UU.  Negra o Afroamericana
# 94  Cierpiszewski  Caroline    29  Femenino    Polonia  Negra o Afroamericana
# 95        DiNocco      Lily    39  Femenino     EE.UU.  Negra o Afroamericana
# 96         Sander    Kamrin    29  Femenino     EE.UU.  Negra o Afroamericana
# 97         Gentry   Mildred    27  Femenino     EE.UU.  Negra o Afroamericana
#
#    Fecha_de_inicio              Departamento                         Posición  \
# 0       2013-11-11    Ingeniería de Software              Ingeniero de ventas
# 1       2015-03-30                     TI/SI           Ingeniero de redes Sr.
# 2       2014-11-10                     TI/SI  Administrador de bases de datos
# 3       2015-02-16  Oficinas Administrativas                     Contador Sr.
# 4       2012-04-02                Producción         Técnico de producción II
# ..             ...                       ...                              ...
# 93      2011-07-05                Producción         Técnico de producción II
# 94      2011-10-03                Producción          Técnico de producción I
# 95      2013-01-07                Producción          Técnico de producción I
# 96      2014-09-29                Producción          Técnico de producción I
# 97      2015-03-30                Producción          Técnico de producción I
#
#      Salario
# 0   115460.8
# 1   114816.0
# 2    88920.0
# 3    72696.0
# 4    54080.0
# ..       ...
# 93   46800.0
# 94   45760.0
# 95   45760.0
# 96   43680.0
# 97   39520.0
#
# [98 rows x 10 columns]
